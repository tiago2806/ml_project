# %%
import sys
sys.path.append("../src")

from datacleaning import clean_data, handle_datatypes, check_impossible_values

# %% [markdown]
# perguntar ao stor:
#
# - nan em complaints assumir como 0?

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\laura\\Desktop\\ML II\\ml_project\\notebooks'

# %%
import pandas as pd

# %% [markdown]
# #IDS SALTAM NUMERO A FRENTE, O QUE FAZER , manter a numeracao que ja vem_
#
# DETETAR OUTLIERS COM DBSCAN

# %%
#perceber bem o que é sobre o dataset

#IDS SALTAM NUMERO A FRENTE, O QUE FAZER , manter a numeracao que ja vem? ok, nao fazer isto pq tira a ligacao dos dois datasets ver istooooo

#ver as birthdates, maybe dar match das datas com o msc e bsc?

#OUTLIERS COM DBSCAN

#meter loyalty number binario

#adicionar validation rules talvez? ou explicar pelo menos???????

#tirar o bsc e o msc e criar uma coluna com isso


# requirements.txt ???''''' ver

#ver se ha impossible values

# %%
dataset = pd.read_csv(r'../data/customer_info.csv',index_col=0)

# %%
print(dataset.shape)
dataset.head()
# Out:
# (33038, 24)
#                      customer_name customer_gender   customer_birthdate  \
# customer_id
# 3            Bsc. Crystal Kitchens          female  02/12/1970 01:36 PM
# 4               Bsc. Glenda Bauman          female  11/13/1975 06:58 PM
# 5            Msc. Antonio Campbell            male  09/10/1971 10:07 AM
# 7                     John Kelling            male  10/23/1982 11:20 AM
# 8                  Arthur Dematteo            male  08/04/1969 10:22 PM
#
#              kids_home  teens_home  number_complaints  \
# customer_id
# 3                  1.0         1.0                1.0
# 4                  1.0         0.0                0.0
# 5                  0.0         0.0                NaN
# 7                  0.0         0.0                2.0
# 8                  0.0         0.0                3.0
#
#              distinct_stores_visited  lifetime_spend_groceries  \
# customer_id
# 3                                3.0                   11731.0
# ...

# %% [markdown]
# ### **Checking Impossible Values**

# %% [markdown]
# # age >0
# # kids_home teens_home number_complaints distincts> 0 e nao pode ser decimal
# # lifetime spend.... >0
# # typical hour 6 < hour < 24
# #percenteage < 100 >0
# # year first transaction menor q o ano atual
# # latitude -90 e 90 longitude -180 e 180
# # age >0

# %%
dataset['typical_hour'].value_counts()
# Out:
# typical_hour
# 8.0     4184
# 14.0    3459
# 7.0     2663
# 9.0     2453
# 10.0    2332
# 11.0    2277
# 12.0    1850
# 6.0     1731
# 13.0    1559
# 23.0    1280
# 15.0    1267
# 16.0    1174
# 17.0    1145
# 18.0    1125
# 19.0    1072
# 20.0    1011
# 21.0     985
# 22.0     810
# Name: count, dtype: int64

# %%
df_teste = handle_datatypes(dataset)
df_teste = check_impossible_values(df_teste)

# Vê quem é que está 100% vazio
print(df_teste.isna().sum())
# Out:
# c:\Users\laura\Desktop\ML II\ml_project\notebooks\../src\datacleaning.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dataset['customer_birthdate'] = pd.to_datetime(dataset['customer_birthdate'], errors='coerce', dayfirst=True)
# customer_name                                  0
# customer_gender                                0
# kids_home                                    330
# teens_home                                   330
# number_complaints                            661
# distinct_stores_visited                      330
# lifetime_spend_groceries                       0
# lifetime_spend_electronics                   661
# typical_hour                               33038
# lifetime_spend_vegetables                    661
# lifetime_spend_nonalcohol_drinks               0
# lifetime_spend_alcohol_drinks                330
# ...

# %%
clean_df = clean_data(dataset)
# Out:
# c:\Users\laura\Desktop\ML II\ml_project\notebooks\../src\datacleaning.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dataset['customer_birthdate'] = pd.to_datetime(dataset['customer_birthdate'], errors='coerce', dayfirst=True)
# c:\Users\laura\anaconda3\envs\ML\Lib\site-packages\sklearn\utils\extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# c:\Users\laura\anaconda3\envs\ML\Lib\site-packages\sklearn\utils\extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# c:\Users\laura\anaconda3\envs\ML\Lib\site-packages\sklearn\utils\extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# ...

# %%
dataset.isnull().sum()
# Out:
# customer_name                                  0
# customer_gender                                0
# customer_birthdate                           165
# kids_home                                    330
# teens_home                                   330
# number_complaints                            661
# distinct_stores_visited                      330
# lifetime_spend_groceries                       0
# lifetime_spend_electronics                   661
# typical_hour                                 661
# lifetime_spend_vegetables                    661
# lifetime_spend_nonalcohol_drinks               0
# lifetime_spend_alcohol_drinks                330
# lifetime_spend_meat                          661
# lifetime_spend_fish                          991
# lifetime_spend_hygiene                       330
# lifetime_spend_videogames                    661
# lifetime_spend_petfood                       661
# lifetime_total_distinct_products               0
# ...

# %% [markdown]
# ### **Handling Data Types**

# %%
dataset.dtypes
# Out:
# customer_name                               object
# customer_gender                             object
# customer_birthdate                          object
# kids_home                                  float64
# teens_home                                 float64
# number_complaints                          float64
# distinct_stores_visited                    float64
# lifetime_spend_groceries                   float64
# lifetime_spend_electronics                 float64
# typical_hour                               float64
# lifetime_spend_vegetables                  float64
# lifetime_spend_nonalcohol_drinks           float64
# lifetime_spend_alcohol_drinks              float64
# lifetime_spend_meat                        float64
# lifetime_spend_fish                        float64
# lifetime_spend_hygiene                     float64
# lifetime_spend_videogames                  float64
# lifetime_spend_petfood                     float64
# ...

# %% [markdown]
# ### **Drop duplicates**

# %%
dataset.drop_duplicates()
# Out:
#                      customer_name customer_gender   customer_birthdate  \
# customer_id
# 3            Bsc. Crystal Kitchens          female  02/12/1970 01:36 PM
# 4               Bsc. Glenda Bauman          female  11/13/1975 06:58 PM
# 5            Msc. Antonio Campbell            male  09/10/1971 10:07 AM
# 7                     John Kelling            male  10/23/1982 11:20 AM
# 8                  Arthur Dematteo            male  08/04/1969 10:22 PM
# ...                            ...             ...                  ...
# 39996                Joshua Howard            male  05/16/1973 02:04 PM
# 39997                Anthony Hines            male  05/10/1955 01:19 AM
# 39998               Edna Hasselman          female  05/15/1945 11:09 PM
# 39999                George Kramer            male  05/25/1951 09:02 PM
# 40000                Sammie Wright          female  07/09/1990 10:27 AM
#
#              kids_home  teens_home  number_complaints  \
# customer_id
# ...

# %%
dataset['typical_hour'].value_counts()
# Out:
# typical_hour
# 8.0     4184
# 14.0    3459
# 7.0     2663
# 9.0     2453
# 10.0    2332
# 11.0    2277
# 12.0    1850
# 6.0     1731
# 13.0    1559
# 23.0    1280
# 15.0    1267
# 16.0    1174
# 17.0    1145
# 18.0    1125
# 19.0    1072
# 20.0    1011
# 21.0     985
# 22.0     810
# Name: count, dtype: int64

# %% [markdown]
# ### **Handling Missing Values**

# %%
dataset.isnull().sum()
# Out:
# customer_name                                  0
# customer_gender                                0
# customer_birthdate                           165
# kids_home                                    330
# teens_home                                   330
# number_complaints                            661
# distinct_stores_visited                      330
# lifetime_spend_groceries                       0
# lifetime_spend_electronics                   661
# typical_hour                                 661
# lifetime_spend_vegetables                    661
# lifetime_spend_nonalcohol_drinks               0
# lifetime_spend_alcohol_drinks                330
# lifetime_spend_meat                          661
# lifetime_spend_fish                          991
# lifetime_spend_hygiene                       330
# lifetime_spend_videogames                    661
# lifetime_spend_petfood                       661
# lifetime_total_distinct_products               0
# ...

# %%
dataset.head(10)
# Out:
#                      customer_name customer_gender   customer_birthdate  \
# customer_id
# 3            Bsc. Crystal Kitchens          female  02/12/1970 01:36 PM
# 4               Bsc. Glenda Bauman          female  11/13/1975 06:58 PM
# 5            Msc. Antonio Campbell            male  09/10/1971 10:07 AM
# 7                     John Kelling            male  10/23/1982 11:20 AM
# 8                  Arthur Dematteo            male  08/04/1969 10:22 PM
# 9               Msc. Nadine Garcia          female  10/09/1968 04:01 AM
# 10              Phd. Franklin Alba            male  06/09/1971 05:08 AM
# 11             Bsc. Robert Hansing            male  07/19/1977 10:22 AM
# 12            Phd. Dorothy Pacheco          female  05/19/2000 03:02 AM
# 14             Msc. Arron Burgener            male  11/28/1948 07:53 PM
#
#              kids_home  teens_home  number_complaints  \
# customer_id
# 3                  1.0         1.0                1.0
# ...

# %%
clean_df.isnull().sum()
# Out:
# customer_name                              0
# customer_gender                            0
# kids_home                                  0
# teens_home                                 0
# number_complaints                          0
# distinct_stores_visited                    0
# lifetime_spend_groceries                   0
# lifetime_spend_electronics                 0
# typical_hour                               0
# lifetime_spend_vegetables                  0
# lifetime_spend_nonalcohol_drinks           0
# lifetime_spend_alcohol_drinks              0
# lifetime_spend_meat                        0
# lifetime_spend_fish                        0
# lifetime_spend_hygiene                     0
# lifetime_spend_videogames                  0
# lifetime_spend_petfood                     0
# lifetime_total_distinct_products           0
# percentage_of_products_bought_promotion    0
# year_first_transaction                     0
# loyalty_card_number                        0
# ...

# %%
clean_df['kids_home'].value_counts()
# Out:
# kids_home
# 1    16208
# 0     9276
# 2     4955
# 3     1102
# 4      663
# 5      433
# 6      243
# 7      106
# 8       52
# Name: count, dtype: Int64

# %%
clean_data = c

# %%
dataset['number_complaints'].value_counts()
dataset['distinct_stores_visited'].value_counts()
dataset[dataset['lifetime_spend_alcohol_drinks'] < 0]
dataset[dataset['lifetime_spend_electronics' ] < 0]
dataset[dataset['lifetime_spend_groceries'] < 0]
dataset[dataset['lifetime_spend_home_furnishing'] < 0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\laura\anaconda3\envs\ML\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lifetime_spend_home_furnishing'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 6
# ...

# %%
dataset[dataset['customer_birthdate'].isnull()]

#conditional imputation
# Out:
#                        customer_name customer_gender customer_birthdate  \
# customer_id
# 401               Msc. Robert Zamora            male                NaN
# 473                   Bsc. Nikki Ali          female                NaN
# 526          Bsc. Theodore Hernandez            male                NaN
# 580                 Phd. Steve Ligon            male                NaN
# 863              Phd. Sergio Johnson            male                NaN
# ...                              ...             ...                ...
# 39012                 Suzanne Harmon          female                NaN
# 39413                  Thomas Bowman            male                NaN
# 39595                  Bettye Murphy          female                NaN
# 39857                   Donald Wylie            male                NaN
# 39881                     Chet Burns            male                NaN
#
#              kids_home  teens_home  number_complaints  \
# customer_id
# ...

# %%
#customer birthdate

# %%
#kids home

# %%
#teens home

# %%
dataset['number_complaints'].unique()
# Out:
# array([ 1.,  0., nan,  2.,  3.,  5.,  6.,  4.,  7.])
