# %% [markdown]
# <div class="alert alert-info" style="background-color: #E3F2FD; color: #0D47A1; border: 1px solid #90CAF9; border-radius: 5px; padding: 15px;">
#     <b>💡 Methodological Note:</b> We used KNN Imputation with 7 neighbors because it preserves the mathematical relationships between customer spending behaviors better than simple mean imputation.
# </div>
